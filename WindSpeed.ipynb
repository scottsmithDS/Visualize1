# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

CityData = pd.read_csv("../cities.csv")

# %%
CityData = pd.DataFrame(CityData)

# %%
lat = CityData['Lat']
MaxTemp = CityData['Max Temp']
WindSpeed = CityData['Wind Speed']
Cloudiness = CityData['Cloudiness']
Humidity = CityData['Humidity']

# %%
plt.scatter(lat, WindSpeed, marker="o", facecolors="red", edgecolors="black")
plt.title("Latitude & Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("WindSpeed")
plt.savefig("Lat&WindSpeed.png")
