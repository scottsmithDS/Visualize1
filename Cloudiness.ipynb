# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

CityData = pd.read_csv("../cities.csv")

# %%
CityData = pd.DataFrame(CityData)

# %%
lat = CityData['Lat']
MaxTemp = CityData['Max Temp']
WindSpeed = CityData['Wind Speed']
Cloudiness = CityData['Cloudiness']
Humidity = CityData['Humidity']

# %%
CL = plt.scatter(lat, Cloudiness, marker="o", facecolors="red", edgecolors="black")

plt.title("Latitude & Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.savefig("Lat&Cloudiness.png")
